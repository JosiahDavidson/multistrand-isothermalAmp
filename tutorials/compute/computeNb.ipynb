# %% [markdown]
# # Compute using multistrand 2.2 and NUPACK
#
# This notebook is used for the calling the sample/setup methods in multistrand 2.2 from a jupyter notebook interface.

# %%
import importlib
import rate

importlib.reload(rate)
# Out:
# <module 'rate' from '/Users/josiah.davidson/Development/git/personal/multistrand-isothermalAmp/tutorials/compute/rate.py'>

# %%
result = rate.main_nbCall("hybridization", "ATCGTA", True, sodium=50E-3, magnesium=8E-3, temperature=65.0)
# Out:
# 2025-02-18 17:35:00   Starting Multistrand 2.2  (c) 2008-2025 Caltech
#
# Running first step mode simulations for ATCGTA (with Boltzmann sampling)...
#
# Start states:
# Complex:
#          Name: 'automatic44'
#      Sequence: ATCGTA
#     Structure: ......
#       Strands: ['top']
#     Boltzmann: True
#   Supersample: 1
#
# Complex:
#          Name: 'automatic45'
#      Sequence: TACGAT
#     Structure: ......
#       Strands: ['top*']
#     Boltzmann: True
#   Supersample: 1
#
# Stop conditions:
# Stop Condition, tag:SUCCESS
#   Sequence  0: ATCGTA+TACGAT
#   Structure 0: ((((((+))))))
#
# Stop Condition, tag:FAILURE
#   Sequence  0: ATCGTA
#   Structure 0: ......
#
# Using Results Type: FirstStepRate
# Computing 1000 trials, using 10 threads ..
#  .. and rolling 100 trajectories per thread until 500 successful trials occur.
#
# nForward = 53
# nReverse = 947
#
# nForward = 108
# nReverse = 1892
#
# nForward = 108
# nReverse = 1892
#
# nForward = 163
# nReverse = 2737
#
# ...

# %%
result

# %%
from multistrand import objects, options, system

# %%
help(objects)
# Out:
# Help on module multistrand.objects in multistrand:
#
# NAME
#     multistrand.objects - Objects module to get the useful names into the correct namespace.
#
# CLASSES
#     builtins.object
#         Complex
#         Domain
#             ComplementaryDomain
#         StopCondition
#             Macrostate
#         Strand
#             ComplementaryStrand
#
#     class ComplementaryDomain(Domain)
#      |  ComplementaryDomain(complemented_domain)
#      |
#      |  Represents a complemented domain. Note that this is always
#      |  defined in terms of an original domain and does not have the same
#      |  data members, instead providing an interface to the complementary
#      |  members.
#      |
#      |  Method resolution order:
#      |      ComplementaryDomain
#      |      Domain
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __eq__(self, other: 'ComplementaryDomain')
#      |      Compare domains syntactically.
#      |
# ...
